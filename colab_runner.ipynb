# %%
# !git clone https://github.com/AarushRathore1729/Simplismart_Assign.git
# %cd Simplismart_Assign
# !apt-get update && apt-get install -y ffmpeg
# !pip install -r requirements.txt
# !pip install torchcodec
# Install GPU-enabled PyTorch (Colab usually has it, but good to ensure)
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Cloning into 'Simplismart_Assign'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 26 (delta 6), reused 24 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (26/26), 10.76 KiB | 10.76 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /content/Simplismart_Assign/Simplismart_Assign/Simplismart_Assign/Simplismart_Assign
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# ...

# %% [markdown]
# ## Run Benchmark
# This runs the speculative decoding benchmark using `whisper-large-v3` (target) and `whisper-tiny` (draft).

# %%
# !git pull
# !python run.py --target-model openai/whisper-large-v3 --draft-model openai/whisper-tiny --dataset hf-internal-testing/librispeech_asr_dummy --split validation --max-samples 10
# Out:
# Already up to date.
# 2025-12-19 07:09:30.552387: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766128170.579807   14148 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766128170.590632   14148 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766128170.606933   14148 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## View Results

# %%
import json
with open("results.json", "r") as f:
    print(json.dumps(json.load(f), indent=2))
# Out:
# {
#   "config": {
#     "top_p": 0.0,
#     "draft_k": 6,
#     "temperature": 1.0,
#     "max_new_tokens": 128,
#     "dataset_size": 10
#   },
#   "baseline": {
#     "total_time": 13.59,
#     "avg_time": 1.3592,
#     "wer": 0.1024
#   },
#   "speculative": {
#     "total_time": 8.66,
#     "avg_time": 0.8656,
#     "wer": 0.1024
#   },
#   "speedup": 1.57,
#   "samples": [
#     {
#       "reference": "mister quilter is the apostle of the middle classes and we are glad to welcome his gospel",
#       "baseline": "mr. quilter is the apostle of the middle classes, and we are glad to welcome his gospel.",
#       "speculative": "\"mr. quilter is the apostle of the middle classes, and we are glad to welcome his gospel."
#     },
#     {
#       "reference": "nor is mister quilter's manner less interesting than his matter",
#       "baseline": "nor is mr. quilter's manner less interesting than his matter.",
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
files.download('results.json')

# %%
# !python run.py --experiment --target-model openai/whisper-large-v3 --draft-model openai/whisper-tiny --dataset hf-internal-testing/librispeech_asr_dummy --split validation --max-samples 10
# Out:
# 2025-12-19 07:18:21.228621: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766128701.248338   16680 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766128701.256125   16680 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766128701.271653   16680 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
from google.colab import files
files.download('results.json')
